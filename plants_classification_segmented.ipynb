# %%
import pandas as pd
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import time
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
sns.set_style('darkgrid')
import shutil
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import time
from tqdm import tqdm
from sklearn.metrics import f1_score
import glob

# %%
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199
print ('Modules loaded')
# Out:
# Modules loaded

# %%
# Reading input images and assigning labels based on folder names
print(os.listdir("data/for_image"))


#Capturing training data and labels into respective lists
train_images = []
train_labels = [] 
dir='data/for_image/train'


for label in os.listdir(dir):
    label_path = os.path.join(dir, label)
    print(label)
    for img_path in glob.glob(os.path.join(label_path, "*.JPG")):
        print('inside')    
        print(img_path)
        train_images.append(img_path)
        train_labels.append(label)
# Out:
# ['valid', 'test', 'train']
# Pongamia Pinnata diseased (P7b)
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0207.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0213.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0039.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0011.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0159.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0171.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0165.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0164.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0170.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0158.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0038.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0212.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0206.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0238.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0210.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0204.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0012.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0166.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0172.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0199.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0198.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0173.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0167.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0013.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0205.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0211.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0239.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0215.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0201.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0229.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0017.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0163.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0177.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0188.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0189.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0176.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0162.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0016.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0228.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0200.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0214.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0202.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0216.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0014.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0028.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0174.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0160.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0148.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0149.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0161.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0175.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0029.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0015.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0217.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0203.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0258.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0264.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0270.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0066.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0072.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0099.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0112.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0106.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0107.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0113.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0098.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0073.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0067.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0271.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0265.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0259.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0273.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0267.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0059.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0071.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0065.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0139.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0105.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0111.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0110.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0104.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0138.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0064.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0070.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0058.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0266.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0272.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0262.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0074.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0060.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0048.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0100.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0114.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0128.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0129.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0115.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0101.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0049.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0061.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0075.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0263.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0261.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0275.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0249.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0063.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0077.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0088.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0117.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0103.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0102.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0116.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0089.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0076.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0062.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0248.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0274.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0260.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0245.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0251.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0047.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0053.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0084.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0090.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0133.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0127.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0126.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0132.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0091.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0085.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0052.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0046.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0250.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0244.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0252.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0246.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0078.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0050.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0044.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0093.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0087.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0118.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0124.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0130.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0131.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0125.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0119.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0086.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0092.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0045.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0051.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0079.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0247.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0253.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0257.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0243.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0055.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0041.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0069.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0096.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0082.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0121.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0135.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0109.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0108.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0134.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0120.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0083.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0097.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0068.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0040.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0054.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0242.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0256.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0240.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0254.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0268.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0042.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0056.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0081.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0095.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0136.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0122.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0123.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0137.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0094.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0080.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0057.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0043.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0269.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0255.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0241.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0226.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0232.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0018.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0024.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0030.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0178.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0150.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0144.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0193.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0187.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0186.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0192.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0145.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0151.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0179.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0031.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0025.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0019.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0233.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0227.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0219.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0231.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0225.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0033.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0027.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0147.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0153.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0184.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0190.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0191.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0185.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0152.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0146.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0026.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0032.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0224.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0230.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0218.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0234.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0220.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0208.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0036.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0022.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0142.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0156.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0181.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0195.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0194.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0180.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0157.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0143.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0023.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0037.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0209.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0221.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0235.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0223.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0237.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0021.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0035.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0155.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0141.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0169.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0196.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0182.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0183.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0197.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0168.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0140.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0154.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0034.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0020.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0236.JPG
# inside
# for_image/train/Pongamia Pinnata diseased (P7b)/0019_0222.JPG
# Arjun healthy (P1b)
# inside
# for_image/train/Arjun healthy (P1b)/0002_0065.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0071.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0059.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0111.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0105.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0139.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0138.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0104.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0110.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0058.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0070.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0064.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0099.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0072.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0066.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0106.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0112.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0113.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0107.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0067.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0073.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0098.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0088.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0077.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0063.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0103.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0117.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0116.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0102.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0062.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0076.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0089.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0048.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0060.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0074.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0128.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0114.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0100.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0101.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0115.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0129.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0075.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0061.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0049.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0012.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0204.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0210.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0199.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0172.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0166.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0167.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0173.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0198.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0211.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0205.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0013.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0011.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0039.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0213.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0207.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0165.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0171.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0159.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0158.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0170.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0164.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0206.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0212.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0038.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0028.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0014.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0216.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0202.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0148.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0160.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0174.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0175.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0161.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0149.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0203.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0217.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0015.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0029.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0017.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0201.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0215.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0188.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0177.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0163.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0162.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0176.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0189.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0214.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0200.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0016.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0027.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0033.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0219.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0190.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0184.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0153.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0147.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0146.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0152.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0185.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0191.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0218.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0032.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0026.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0030.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0024.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0018.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0187.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0193.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0144.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0150.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0178.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0179.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0151.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0145.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0192.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0186.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0019.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0025.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0031.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0035.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0021.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0182.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0196.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0169.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0141.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0155.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0154.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0140.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0168.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0197.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0183.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0020.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0034.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0022.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0036.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0208.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0220.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0195.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0181.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0156.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0142.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0143.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0157.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0180.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0194.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0209.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0037.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0023.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0087.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0093.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0044.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0050.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0078.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0130.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0124.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0118.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0119.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0125.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0131.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0079.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0051.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0045.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0092.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0086.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0090.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0084.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0053.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0047.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0127.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0133.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0132.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0126.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0046.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0052.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0085.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0091.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0095.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0081.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0056.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0042.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0122.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0136.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0137.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0123.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0043.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0057.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0080.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0094.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0082.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0096.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0069.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0041.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0055.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0109.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0135.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0121.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0120.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0134.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0108.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0054.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0040.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0068.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0097.JPG
# inside
# for_image/train/Arjun healthy (P1b)/0002_0083.JPG
# Alstonia Scholaris diseased (P2a)
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0117.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0103.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0249.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0088.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0063.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0077.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0076.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0062.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0089.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0248.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0102.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0116.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0100.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0114.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0128.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0074.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0060.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0048.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0049.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0061.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0075.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0129.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0115.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0101.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0139.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0105.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0111.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0059.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0071.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0065.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0064.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0070.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0058.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0110.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0104.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0138.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0112.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0106.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0099.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0066.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0072.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0073.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0067.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0098.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0107.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0113.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0174.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0160.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0148.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0202.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0216.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0014.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0028.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0029.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0015.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0217.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0203.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0149.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0161.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0175.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0188.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0163.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0177.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0215.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0201.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0229.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0017.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0016.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0228.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0200.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0214.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0176.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0162.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0189.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0199.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0166.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0172.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0238.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0210.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0204.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0012.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0013.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0205.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0211.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0239.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0173.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0167.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0198.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0159.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0171.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0165.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0207.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0213.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0039.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0011.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0038.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0212.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0206.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0164.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0170.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0158.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0196.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0182.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0155.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0141.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0169.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0223.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0237.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0021.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0035.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0034.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0020.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0236.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0222.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0168.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0140.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0154.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0183.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0197.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0181.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0195.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0142.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0156.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0234.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0220.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0208.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0036.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0022.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0023.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0037.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0209.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0221.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0235.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0157.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0143.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0194.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0180.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0184.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0190.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0147.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0153.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0219.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0231.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0225.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0033.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0027.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0026.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0032.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0224.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0230.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0218.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0152.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0146.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0191.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0185.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0193.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0187.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0178.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0150.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0144.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0226.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0232.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0018.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0024.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0030.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0031.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0025.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0019.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0233.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0227.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0145.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0151.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0179.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0186.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0192.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0136.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0122.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0240.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0254.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0081.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0095.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0042.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0056.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0057.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0043.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0094.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0080.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0241.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0123.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0137.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0121.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0135.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0109.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0243.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0096.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0082.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0055.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0041.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0069.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0068.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0040.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0054.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0083.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0097.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0242.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0108.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0134.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0120.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0118.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0124.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0130.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0252.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0246.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0093.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0087.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0078.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0050.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0044.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0045.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0051.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0079.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0086.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0092.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0247.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0253.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0131.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0125.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0119.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0133.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0127.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0245.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0251.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0084.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0090.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0047.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0053.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0052.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0046.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0091.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0085.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0250.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0244.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0126.JPG
# inside
# for_image/train/Alstonia Scholaris diseased (P2a)/0014_0132.JPG
# Gauva healthy (P3a)
# inside
# for_image/train/Gauva healthy (P3a)/0004_0202.JPG
# inside
# for_image/train/Gauva healthy (P3a)/0004_0216.JPG
# inside
# for_image/train/Gauva healthy (P3a)/0004_0028.JPG
# inside
# for_image/train/Gauva healthy (P3a)/0004_0014.JPG
# inside
# for_image/train/Gauva healthy (P3a)/0004_0148.JPG
# ...
# inside
# for_image/train/Mango diseased (P0b)/0012_0228.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0214.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0200.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0016.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0162.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0176.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0189.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0139.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0111.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0105.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0059.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0065.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0071.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0070.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0064.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0058.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0104.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0110.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0138.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0106.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0112.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0099.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0072.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0066.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0258.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0264.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0265.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0259.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0067.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0073.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0098.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0113.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0107.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0103.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0117.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0088.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0077.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0063.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0261.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0249.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0248.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0260.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0062.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0076.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0089.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0116.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0102.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0114.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0100.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0128.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0060.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0074.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0048.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0262.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0263.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0049.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0075.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0061.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0129.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0101.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0115.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0118.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0130.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0124.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0087.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0093.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0078.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0044.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0050.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0246.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0252.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0253.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0247.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0051.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0045.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0079.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0092.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0086.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0125.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0131.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0119.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0127.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0133.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0090.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0084.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0053.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0047.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0251.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0245.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0244.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0250.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0046.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0052.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0085.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0091.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0132.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0126.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0122.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0136.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0095.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0081.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0056.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0042.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0254.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0240.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0241.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0255.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0043.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0057.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0080.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0094.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0137.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0123.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0135.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0121.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0109.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0082.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0096.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0041.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0055.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0069.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0243.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0257.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0256.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0242.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0068.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0054.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0040.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0097.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0083.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0108.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0120.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0134.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0190.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0184.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0153.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0147.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0027.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0033.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0219.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0225.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0231.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0230.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0224.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0218.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0032.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0026.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0146.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0152.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0185.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0191.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0187.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0193.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0178.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0144.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0150.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0018.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0030.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0024.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0232.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0226.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0227.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0233.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0025.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0031.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0019.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0151.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0145.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0179.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0192.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0186.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0182.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0196.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0141.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0155.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0169.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0035.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0021.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0237.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0223.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0222.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0236.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0020.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0034.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0168.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0154.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0140.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0197.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0183.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0195.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0181.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0156.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0142.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0022.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0036.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0220.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0234.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0208.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0209.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0235.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0221.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0037.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0023.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0143.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0157.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0180.JPG
# inside
# for_image/train/Mango diseased (P0b)/0012_0194.JPG
# Lemon diseased (P10b)
# inside
# for_image/train/Lemon diseased (P10b)/0021_0075.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0061.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0049.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0048.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0060.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0074.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0062.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0076.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0077.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0063.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0067.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0073.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0072.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0066.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0058.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0070.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0064.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0065.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0071.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0059.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0016.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0017.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0015.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0029.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0028.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0014.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0038.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0011.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0039.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0013.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0012.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0037.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0023.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0022.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0036.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0020.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0034.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0035.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0021.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0019.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0025.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0031.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0030.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0024.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0018.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0032.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0026.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0027.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0033.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0054.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0040.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0068.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0069.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0041.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0055.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0043.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0057.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0056.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0042.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0046.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0052.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0053.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0047.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0051.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0045.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0044.JPG
# inside
# for_image/train/Lemon diseased (P10b)/0021_0050.JPG

# %%
train_df=pd.DataFrame({'image':train_images,'label':train_labels})

# %%
train_df.head()
# Out:
#                                                            image
# 0  for_image/train/Pongamia Pinnata diseased (P7b)/0019_0207.JPG  \
# 1  for_image/train/Pongamia Pinnata diseased (P7b)/0019_0213.JPG
# 2  for_image/train/Pongamia Pinnata diseased (P7b)/0019_0039.JPG
# 3  for_image/train/Pongamia Pinnata diseased (P7b)/0019_0011.JPG
# 4  for_image/train/Pongamia Pinnata diseased (P7b)/0019_0159.JPG
#
#                              label
# 0  Pongamia Pinnata diseased (P7b)
# 1  Pongamia Pinnata diseased (P7b)
# 2  Pongamia Pinnata diseased (P7b)
# 3  Pongamia Pinnata diseased (P7b)
# 4  Pongamia Pinnata diseased (P7b)

# %%
# Reading input images and assigning labels based on folder names
print(os.listdir("data/for_image"))

SIZE = (200,300)  #Resize images

#Capturing training data and labels into respective lists
valid_images = []
valid_labels = [] 
dir = 'data/for_image/valid'


for label in os.listdir(dir):
    label_path = os.path.join(dir, label)
    print(label)
    for img_path in glob.glob(os.path.join(label_path, "*.JPG")):
        print('inside')    
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        valid_images.append(img_path)
        valid_labels.append(label)
# Out:
# ['valid', 'test', 'train']
# Pongamia Pinnata diseased (P7b)
# inside
# for_image/valid/Pongamia Pinnata diseased (P7b)/0019_0010.JPG
# inside
# for_image/valid/Pongamia Pinnata diseased (P7b)/0019_0006.JPG
# inside
# for_image/valid/Pongamia Pinnata diseased (P7b)/0019_0007.JPG
# inside
# for_image/valid/Pongamia Pinnata diseased (P7b)/0019_0009.JPG
# inside
# for_image/valid/Pongamia Pinnata diseased (P7b)/0019_0008.JPG
# Arjun healthy (P1b)
# inside
# for_image/valid/Arjun healthy (P1b)/0002_0005.JPG
# inside
# for_image/valid/Arjun healthy (P1b)/0002_0004.JPG
# inside
# for_image/valid/Arjun healthy (P1b)/0002_0001.JPG
# inside
# for_image/valid/Arjun healthy (P1b)/0002_0003.JPG
# inside
# for_image/valid/Arjun healthy (P1b)/0002_0002.JPG
# Alstonia Scholaris diseased (P2a)
# inside
# for_image/valid/Alstonia Scholaris diseased (P2a)/0014_0001.JPG
# inside
# for_image/valid/Alstonia Scholaris diseased (P2a)/0014_0003.JPG
# inside
# for_image/valid/Alstonia Scholaris diseased (P2a)/0014_0002.JPG
# inside
# for_image/valid/Alstonia Scholaris diseased (P2a)/0014_0005.JPG
# inside
# for_image/valid/Alstonia Scholaris diseased (P2a)/0014_0004.JPG
# Gauva healthy (P3a)
# inside
# for_image/valid/Gauva healthy (P3a)/0004_0001.JPG
# inside
# for_image/valid/Gauva healthy (P3a)/0004_0003.JPG
# inside
# for_image/valid/Gauva healthy (P3a)/0004_0002.JPG
# inside
# for_image/valid/Gauva healthy (P3a)/0004_0005.JPG
# inside
# for_image/valid/Gauva healthy (P3a)/0004_0004.JPG
# Chinar diseased (P11b)
# inside
# for_image/valid/Chinar diseased (P11b)/0022_0004.JPG
# inside
# for_image/valid/Chinar diseased (P11b)/0022_0005.JPG
# inside
# for_image/valid/Chinar diseased (P11b)/0022_0001.JPG
# inside
# for_image/valid/Chinar diseased (P11b)/0022_0002.JPG
# inside
# for_image/valid/Chinar diseased (P11b)/0022_0003.JPG
# Arjun diseased (P1a)
# inside
# for_image/valid/Arjun diseased (P1a)/0013_0005.JPG
# inside
# for_image/valid/Arjun diseased (P1a)/0013_0004.JPG
# inside
# for_image/valid/Arjun diseased (P1a)/0013_0001.JPG
# inside
# for_image/valid/Arjun diseased (P1a)/0013_0003.JPG
# inside
# for_image/valid/Arjun diseased (P1a)/0013_0002.JPG
# Pomegranate healthy (P9a)
# inside
# for_image/valid/Pomegranate healthy (P9a)/0009_0010.JPG
# inside
# for_image/valid/Pomegranate healthy (P9a)/0009_0006.JPG
# inside
# for_image/valid/Pomegranate healthy (P9a)/0009_0007.JPG
# inside
# for_image/valid/Pomegranate healthy (P9a)/0009_0009.JPG
# inside
# for_image/valid/Pomegranate healthy (P9a)/0009_0008.JPG
# Chinar healthy (P11a)
# inside
# for_image/valid/Chinar healthy (P11a)/0011_0003.JPG
# inside
# for_image/valid/Chinar healthy (P11a)/0011_0002.JPG
# inside
# for_image/valid/Chinar healthy (P11a)/0011_0001.JPG
# inside
# for_image/valid/Chinar healthy (P11a)/0011_0005.JPG
# inside
# for_image/valid/Chinar healthy (P11a)/0011_0004.JPG
# Mango healthy (P0a)
# inside
# for_image/valid/Mango healthy (P0a)/0001_0009.JPG
# inside
# for_image/valid/Mango healthy (P0a)/0001_0008.JPG
# inside
# for_image/valid/Mango healthy (P0a)/0001_0010.JPG
# inside
# for_image/valid/Mango healthy (P0a)/0001_0006.JPG
# inside
# for_image/valid/Mango healthy (P0a)/0001_0007.JPG
# Jatropha healthy (P6a)
# inside
# for_image/valid/Jatropha healthy (P6a)/0006_0009.JPG
# inside
# for_image/valid/Jatropha healthy (P6a)/0006_0008.JPG
# inside
# for_image/valid/Jatropha healthy (P6a)/0006_0010.JPG
# inside
# for_image/valid/Jatropha healthy (P6a)/0006_0006.JPG
# inside
# for_image/valid/Jatropha healthy (P6a)/0006_0007.JPG
# Jatropha diseased (P6b)
# inside
# for_image/valid/Jatropha diseased (P6b)/0018_0010.JPG
# inside
# for_image/valid/Jatropha diseased (P6b)/0018_0006.JPG
# inside
# for_image/valid/Jatropha diseased (P6b)/0018_0007.JPG
# inside
# for_image/valid/Jatropha diseased (P6b)/0018_0009.JPG
# inside
# for_image/valid/Jatropha diseased (P6b)/0018_0008.JPG
# Jamun diseased (P5b)
# inside
# for_image/valid/Jamun diseased (P5b)/0017_0005.JPG
# inside
# for_image/valid/Jamun diseased (P5b)/0017_0004.JPG
# inside
# for_image/valid/Jamun diseased (P5b)/0017_0003.JPG
# inside
# for_image/valid/Jamun diseased (P5b)/0017_0002.JPG
# inside
# for_image/valid/Jamun diseased (P5b)/0017_0001.JPG
# Jamun healthy (P5a)
# inside
# for_image/valid/Jamun healthy (P5a)/0005_0006.JPG
# inside
# for_image/valid/Jamun healthy (P5a)/0005_0007.JPG
# inside
# for_image/valid/Jamun healthy (P5a)/0005_0010.JPG
# inside
# for_image/valid/Jamun healthy (P5a)/0005_0009.JPG
# inside
# for_image/valid/Jamun healthy (P5a)/0005_0008.JPG
# Lemon healthy (P10a)
# inside
# for_image/valid/Lemon healthy (P10a)/0010_0009.JPG
# inside
# for_image/valid/Lemon healthy (P10a)/0010_0008.JPG
# inside
# for_image/valid/Lemon healthy (P10a)/0010_0010.JPG
# inside
# for_image/valid/Lemon healthy (P10a)/0010_0006.JPG
# inside
# for_image/valid/Lemon healthy (P10a)/0010_0007.JPG
# Pongamia Pinnata healthy (P7a)
# inside
# for_image/valid/Pongamia Pinnata healthy (P7a)/0007_0009.JPG
# inside
# for_image/valid/Pongamia Pinnata healthy (P7a)/0007_0008.JPG
# inside
# for_image/valid/Pongamia Pinnata healthy (P7a)/0007_0010.JPG
# inside
# for_image/valid/Pongamia Pinnata healthy (P7a)/0007_0006.JPG
# inside
# for_image/valid/Pongamia Pinnata healthy (P7a)/0007_0007.JPG
# Bael diseased (P4b)
# inside
# for_image/valid/Bael diseased (P4b)/0016_0005.JPG
# inside
# for_image/valid/Bael diseased (P4b)/0016_0004.JPG
# inside
# for_image/valid/Bael diseased (P4b)/0016_0003.JPG
# inside
# for_image/valid/Bael diseased (P4b)/0016_0002.JPG
# inside
# for_image/valid/Bael diseased (P4b)/0016_0001.JPG
# Gauva diseased (P3b)
# inside
# for_image/valid/Gauva diseased (P3b)/0015_0006.JPG
# inside
# for_image/valid/Gauva diseased (P3b)/0015_0007.JPG
# inside
# for_image/valid/Gauva diseased (P3b)/0015_0010.JPG
# inside
# for_image/valid/Gauva diseased (P3b)/0015_0009.JPG
# inside
# for_image/valid/Gauva diseased (P3b)/0015_0008.JPG
# Alstonia Scholaris healthy (P2b)
# inside
# for_image/valid/Alstonia Scholaris healthy (P2b)/0003_0005.JPG
# inside
# for_image/valid/Alstonia Scholaris healthy (P2b)/0003_0004.JPG
# inside
# for_image/valid/Alstonia Scholaris healthy (P2b)/0003_0001.JPG
# inside
# for_image/valid/Alstonia Scholaris healthy (P2b)/0003_0003.JPG
# inside
# for_image/valid/Alstonia Scholaris healthy (P2b)/0003_0002.JPG
# Pomegranate diseased (P9b)
# inside
# for_image/valid/Pomegranate diseased (P9b)/0020_0010.JPG
# inside
# for_image/valid/Pomegranate diseased (P9b)/0020_0007.JPG
# inside
# for_image/valid/Pomegranate diseased (P9b)/0020_0006.JPG
# inside
# for_image/valid/Pomegranate diseased (P9b)/0020_0008.JPG
# inside
# for_image/valid/Pomegranate diseased (P9b)/0020_0009.JPG
# Basil healthy (P8)
# inside
# for_image/valid/Basil healthy (P8)/0008_0010.JPG
# inside
# for_image/valid/Basil healthy (P8)/0008_0006.JPG
# inside
# for_image/valid/Basil healthy (P8)/0008_0007.JPG
# inside
# for_image/valid/Basil healthy (P8)/0008_0009.JPG
# inside
# for_image/valid/Basil healthy (P8)/0008_0008.JPG
# Mango diseased (P0b)
# inside
# for_image/valid/Mango diseased (P0b)/0012_0006.JPG
# inside
# for_image/valid/Mango diseased (P0b)/0012_0007.JPG
# inside
# for_image/valid/Mango diseased (P0b)/0012_0010.JPG
# inside
# for_image/valid/Mango diseased (P0b)/0012_0009.JPG
# inside
# for_image/valid/Mango diseased (P0b)/0012_0008.JPG
# Lemon diseased (P10b)
# inside
# for_image/valid/Lemon diseased (P10b)/0021_0010.JPG
# inside
# for_image/valid/Lemon diseased (P10b)/0021_0007.JPG
# inside
# for_image/valid/Lemon diseased (P10b)/0021_0006.JPG
# inside
# for_image/valid/Lemon diseased (P10b)/0021_0008.JPG
# inside
# for_image/valid/Lemon diseased (P10b)/0021_0009.JPG

# %%
# Reading input images and assigning labels based on folder names
print(os.listdir("for_image"))

SIZE = (200,300) #Resize images

#Capturing training data and labels into respective lists
test_images = []
test_labels = [] 
dir = 'data/for_image/test'


for label in os.listdir(dir):
    label_path = os.path.join(dir, label)
    print(label)
    for img_path in glob.glob(os.path.join(label_path, "*.JPG")):
        print('inside')    
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img_path)
        test_labels.append(label)
# Out:
# ['valid', 'test', 'train']
# Pongamia Pinnata diseased (P7b)
# inside
# for_image/test/Pongamia Pinnata diseased (P7b)/0019_0005.JPG
# inside
# for_image/test/Pongamia Pinnata diseased (P7b)/0019_0004.JPG
# inside
# for_image/test/Pongamia Pinnata diseased (P7b)/0019_0003.JPG
# inside
# for_image/test/Pongamia Pinnata diseased (P7b)/0019_0002.JPG
# inside
# for_image/test/Pongamia Pinnata diseased (P7b)/0019_0001.JPG
# Arjun healthy (P1b)
# inside
# for_image/test/Arjun healthy (P1b)/0002_0006.JPG
# inside
# for_image/test/Arjun healthy (P1b)/0002_0007.JPG
# inside
# for_image/test/Arjun healthy (P1b)/0002_0010.JPG
# inside
# for_image/test/Arjun healthy (P1b)/0002_0009.JPG
# inside
# for_image/test/Arjun healthy (P1b)/0002_0008.JPG
# Alstonia Scholaris diseased (P2a)
# inside
# for_image/test/Alstonia Scholaris diseased (P2a)/0014_0006.JPG
# inside
# for_image/test/Alstonia Scholaris diseased (P2a)/0014_0007.JPG
# inside
# for_image/test/Alstonia Scholaris diseased (P2a)/0014_0010.JPG
# inside
# for_image/test/Alstonia Scholaris diseased (P2a)/0014_0009.JPG
# inside
# for_image/test/Alstonia Scholaris diseased (P2a)/0014_0008.JPG
# Gauva healthy (P3a)
# inside
# for_image/test/Gauva healthy (P3a)/0004_0006.JPG
# inside
# for_image/test/Gauva healthy (P3a)/0004_0007.JPG
# inside
# for_image/test/Gauva healthy (P3a)/0004_0010.JPG
# inside
# for_image/test/Gauva healthy (P3a)/0004_0009.JPG
# inside
# for_image/test/Gauva healthy (P3a)/0004_0008.JPG
# Chinar diseased (P11b)
# inside
# for_image/test/Chinar diseased (P11b)/0022_0008.JPG
# inside
# for_image/test/Chinar diseased (P11b)/0022_0009.JPG
# inside
# for_image/test/Chinar diseased (P11b)/0022_0007.JPG
# inside
# for_image/test/Chinar diseased (P11b)/0022_0006.JPG
# inside
# for_image/test/Chinar diseased (P11b)/0022_0010.JPG
# Arjun diseased (P1a)
# inside
# for_image/test/Arjun diseased (P1a)/0013_0006.JPG
# inside
# for_image/test/Arjun diseased (P1a)/0013_0007.JPG
# inside
# for_image/test/Arjun diseased (P1a)/0013_0010.JPG
# inside
# for_image/test/Arjun diseased (P1a)/0013_0009.JPG
# inside
# for_image/test/Arjun diseased (P1a)/0013_0008.JPG
# Pomegranate healthy (P9a)
# inside
# for_image/test/Pomegranate healthy (P9a)/0009_0005.JPG
# inside
# for_image/test/Pomegranate healthy (P9a)/0009_0004.JPG
# inside
# for_image/test/Pomegranate healthy (P9a)/0009_0003.JPG
# inside
# for_image/test/Pomegranate healthy (P9a)/0009_0002.JPG
# inside
# for_image/test/Pomegranate healthy (P9a)/0009_0001.JPG
# Chinar healthy (P11a)
# inside
# for_image/test/Chinar healthy (P11a)/0011_0009.JPG
# inside
# for_image/test/Chinar healthy (P11a)/0011_0008.JPG
# inside
# for_image/test/Chinar healthy (P11a)/0011_0010.JPG
# inside
# for_image/test/Chinar healthy (P11a)/0011_0006.JPG
# inside
# for_image/test/Chinar healthy (P11a)/0011_0007.JPG
# Mango healthy (P0a)
# inside
# for_image/test/Mango healthy (P0a)/0001_0003.JPG
# inside
# for_image/test/Mango healthy (P0a)/0001_0002.JPG
# inside
# for_image/test/Mango healthy (P0a)/0001_0001.JPG
# inside
# for_image/test/Mango healthy (P0a)/0001_0005.JPG
# inside
# for_image/test/Mango healthy (P0a)/0001_0004.JPG
# Jatropha healthy (P6a)
# inside
# for_image/test/Jatropha healthy (P6a)/0006_0005.JPG
# inside
# for_image/test/Jatropha healthy (P6a)/0006_0004.JPG
# inside
# for_image/test/Jatropha healthy (P6a)/0006_0003.JPG
# inside
# for_image/test/Jatropha healthy (P6a)/0006_0002.JPG
# inside
# for_image/test/Jatropha healthy (P6a)/0006_0001.JPG
# Jatropha diseased (P6b)
# inside
# for_image/test/Jatropha diseased (P6b)/0018_0005.JPG
# inside
# for_image/test/Jatropha diseased (P6b)/0018_0004.JPG
# inside
# for_image/test/Jatropha diseased (P6b)/0018_0003.JPG
# inside
# for_image/test/Jatropha diseased (P6b)/0018_0002.JPG
# inside
# for_image/test/Jatropha diseased (P6b)/0018_0001.JPG
# Jamun diseased (P5b)
# inside
# for_image/test/Jamun diseased (P5b)/0017_0009.JPG
# inside
# for_image/test/Jamun diseased (P5b)/0017_0008.JPG
# inside
# for_image/test/Jamun diseased (P5b)/0017_0010.JPG
# inside
# for_image/test/Jamun diseased (P5b)/0017_0006.JPG
# inside
# for_image/test/Jamun diseased (P5b)/0017_0007.JPG
# Jamun healthy (P5a)
# inside
# for_image/test/Jamun healthy (P5a)/0005_0001.JPG
# inside
# for_image/test/Jamun healthy (P5a)/0005_0003.JPG
# inside
# for_image/test/Jamun healthy (P5a)/0005_0002.JPG
# inside
# for_image/test/Jamun healthy (P5a)/0005_0005.JPG
# inside
# for_image/test/Jamun healthy (P5a)/0005_0004.JPG
# Lemon healthy (P10a)
# inside
# for_image/test/Lemon healthy (P10a)/0010_0003.JPG
# inside
# for_image/test/Lemon healthy (P10a)/0010_0002.JPG
# inside
# for_image/test/Lemon healthy (P10a)/0010_0001.JPG
# inside
# for_image/test/Lemon healthy (P10a)/0010_0005.JPG
# inside
# for_image/test/Lemon healthy (P10a)/0010_0004.JPG
# Pongamia Pinnata healthy (P7a)
# inside
# for_image/test/Pongamia Pinnata healthy (P7a)/0007_0005.JPG
# inside
# for_image/test/Pongamia Pinnata healthy (P7a)/0007_0004.JPG
# inside
# for_image/test/Pongamia Pinnata healthy (P7a)/0007_0003.JPG
# inside
# for_image/test/Pongamia Pinnata healthy (P7a)/0007_0002.JPG
# inside
# for_image/test/Pongamia Pinnata healthy (P7a)/0007_0001.JPG
# Bael diseased (P4b)
# inside
# for_image/test/Bael diseased (P4b)/0016_0009.JPG
# inside
# for_image/test/Bael diseased (P4b)/0016_0008.JPG
# inside
# for_image/test/Bael diseased (P4b)/0016_0010.JPG
# inside
# for_image/test/Bael diseased (P4b)/0016_0006.JPG
# inside
# for_image/test/Bael diseased (P4b)/0016_0007.JPG
# Gauva diseased (P3b)
# inside
# for_image/test/Gauva diseased (P3b)/0015_0001.JPG
# inside
# for_image/test/Gauva diseased (P3b)/0015_0003.JPG
# inside
# for_image/test/Gauva diseased (P3b)/0015_0002.JPG
# inside
# for_image/test/Gauva diseased (P3b)/0015_0005.JPG
# inside
# for_image/test/Gauva diseased (P3b)/0015_0004.JPG
# Alstonia Scholaris healthy (P2b)
# inside
# for_image/test/Alstonia Scholaris healthy (P2b)/0003_0006.JPG
# inside
# for_image/test/Alstonia Scholaris healthy (P2b)/0003_0007.JPG
# inside
# for_image/test/Alstonia Scholaris healthy (P2b)/0003_0010.JPG
# inside
# for_image/test/Alstonia Scholaris healthy (P2b)/0003_0009.JPG
# inside
# for_image/test/Alstonia Scholaris healthy (P2b)/0003_0008.JPG
# Pomegranate diseased (P9b)
# inside
# for_image/test/Pomegranate diseased (P9b)/0020_0002.JPG
# inside
# for_image/test/Pomegranate diseased (P9b)/0020_0003.JPG
# inside
# for_image/test/Pomegranate diseased (P9b)/0020_0001.JPG
# inside
# for_image/test/Pomegranate diseased (P9b)/0020_0004.JPG
# inside
# for_image/test/Pomegranate diseased (P9b)/0020_0005.JPG
# Basil healthy (P8)
# inside
# for_image/test/Basil healthy (P8)/0008_0005.JPG
# inside
# for_image/test/Basil healthy (P8)/0008_0004.JPG
# inside
# for_image/test/Basil healthy (P8)/0008_0003.JPG
# inside
# for_image/test/Basil healthy (P8)/0008_0002.JPG
# inside
# for_image/test/Basil healthy (P8)/0008_0001.JPG
# Mango diseased (P0b)
# inside
# for_image/test/Mango diseased (P0b)/0012_0005.JPG
# inside
# for_image/test/Mango diseased (P0b)/0012_0004.JPG
# inside
# for_image/test/Mango diseased (P0b)/0012_0001.JPG
# inside
# for_image/test/Mango diseased (P0b)/0012_0003.JPG
# inside
# for_image/test/Mango diseased (P0b)/0012_0002.JPG
# Lemon diseased (P10b)
# inside
# for_image/test/Lemon diseased (P10b)/0021_0002.JPG
# inside
# for_image/test/Lemon diseased (P10b)/0021_0003.JPG
# inside
# for_image/test/Lemon diseased (P10b)/0021_0001.JPG
# inside
# for_image/test/Lemon diseased (P10b)/0021_0004.JPG
# inside
# for_image/test/Lemon diseased (P10b)/0021_0005.JPG

# %%
test_df=pd.DataFrame({'image':test_images,'label':test_labels})
train_df=pd.DataFrame({'image':train_images,'label':train_labels})
valid_df=pd.DataFrame({'image':valid_images,'label':valid_labels})

# %%
def trim(df, max_samples, min_samples, column):
    df=df.copy()
    classes=df[column].unique()
    class_count=len(classes)
    length=len(df)
    print ('dataframe initially is of length ',length, ' with ', class_count, ' classes')
    groups=df.groupby(column)    
    trimmed_df = pd.DataFrame(columns = df.columns)
    groups=df.groupby(column)
    for label in df[column].unique(): 
        group=groups.get_group(label)
        count=len(group)    
        if count > max_samples:
            sampled_group=group.sample(n=max_samples, random_state=123,axis=0)
            trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
        else:
            if count>=min_samples:
                sampled_group=group        
                trimmed_df=pd.concat([trimmed_df, sampled_group], axis=0)
    print('after trimming, the maximum samples in any class is now ',max_samples, ' and the minimum samples in any class is ', min_samples)
    classes=trimmed_df[column].unique()# return this in case some classes have less than min_samples
    class_count=len(classes) # return this in case some classes have less than min_samples
    length=len(trimmed_df)
    print ('the trimmed dataframe now is of length ',length, ' with ', class_count, ' classes')
    return trimmed_df, classes, class_count

# %%
max_samples=200
min_samples=54
column='label'
train_df, classes, class_count=trim(train_df, max_samples, min_samples, column)
# Out:
# dataframe initially is of length  4274  with  22  classes
# after trimming, the maximum samples in any class is now  200  and the minimum samples in any class is  54
# the trimmed dataframe now is of length  3558  with  22  classes

# %%
train_df.groupby(['label']).size().plot.bar(figsize=(15, 5), title='Number of images per class before augmentation')
# Out:
# <Axes: title={'center': 'Number of images per class before augmentation'}, xlabel='label'>

# %%
def balance(df, n, working_dir, img_size):
    df=df.copy()
    print('Initial length of dataframe is ', len(df))
    aug_dir=os.path.join(working_dir, 'aug_seg')# directory to store augmented images
    if os.path.isdir(aug_dir):# start with an empty directory
        shutil.rmtree(aug_dir)
    os.mkdir(aug_dir)        
    for label in df['label'].unique():    
        dir_path=os.path.join(aug_dir,label)    
        os.mkdir(dir_path) # make class directories within aug directory
    # create and store the augmented images  
    total=0
    gen=ImageDataGenerator(horizontal_flip=True,  rotation_range=20, width_shift_range=.2,
                                  height_shift_range=.2, zoom_range=.2)
    groups=df.groupby('label') # group by class
    for label in df['label'].unique():  # for every class               
        group=groups.get_group(label)  # a dataframe holding only rows with the specified label 
        sample_count=len(group)   # determine how many samples there are in this class  
        if sample_count< n: # if the class has less than target number of images
            aug_img_count=0
            delta=n - sample_count  # number of augmented images to create
            target_dir=os.path.join(aug_dir, label)  # define where to write the images
            msg='{0:40s} for class {1:^30s} creating {2:^5s} augmented images'.format(' ', label, str(delta))
            print(msg, '\r', end='') # prints over on the same line
            aug_gen=gen.flow_from_dataframe( group,  x_col='image', y_col=None, target_size=img_size,
                                            class_mode=None, batch_size=1, shuffle=False, 
                                            save_to_dir=target_dir, save_prefix='aug-', color_mode='rgb',
                                            save_format='jpg')
            while aug_img_count<delta:
                images=next(aug_gen)            
                aug_img_count += len(images)
            total +=aug_img_count
    print('Total Augmented images created= ', total)
    # create aug_df and merge with train_df to create composite training set ndf
    aug_fpaths=[]
    aug_labels=[]
    classlist=os.listdir(aug_dir)
    for klass in classlist:
        classpath=os.path.join(aug_dir, klass)     
        flist=os.listdir(classpath)    
        for f in flist:        
            fpath=os.path.join(classpath,f)         
            aug_fpaths.append(fpath)
            aug_labels.append(klass)
    Fseries=pd.Series(aug_fpaths, name='image')
    Lseries=pd.Series(aug_labels, name='label')
    aug_df=pd.concat([Fseries, Lseries], axis=1)         
    df=pd.concat([df,aug_df], axis=0).reset_index(drop=True)
    print('Length of augmented dataframe is now ', len(df))
    return df

# %%
n=200 # number of samples in each class
working_dir=r'./data' # directory to store augmented images
img_size=(200,300) # size of augmented images
train_df=balance(train_df, n, working_dir, img_size)
# Out:
# Initial length of dataframe is  3558
# Found 110 validated image filenames.     for class     Chinar diseased (P11b)     creating  90   augmented images
# Found 93 validated image filenames.      for class     Chinar healthy (P11a)      creating  107  augmented images
# Found 159 validated image filenames.     for class      Mango healthy (P0a)       creating  41   augmented images
# Found 123 validated image filenames.     for class     Jatropha healthy (P6a)     creating  77   augmented images
# Found 114 validated image filenames.     for class    Jatropha diseased (P6b)     creating  86   augmented images
# Found 149 validated image filenames.     for class      Lemon healthy (P10a)      creating  51   augmented images
# Found 107 validated image filenames.     for class      Bael diseased (P4b)       creating  93   augmented images
# Found 131 validated image filenames.     for class      Gauva diseased (P3b)      creating  69   augmented images
# Found 168 validated image filenames.     for class Alstonia Scholaris healthy (P2b) creating  32   augmented images
# Found 137 validated image filenames.     for class       Basil healthy (P8)       creating  63   augmented images
# Found 67 validated image filenames.      for class     Lemon diseased (P10b)      creating  133  augmented images
# Total Augmented images created=  842
# Length of augmented dataframe is now  4400

# %%
train_df.groupby(['label']).size().plot.bar(figsize=(15, 5), title='Number of images per class after augmentation')
# Out:
# <Axes: title={'center': 'Number of images per class after augmentation'}, xlabel='label'>

# %%
def make_gens(batch_size, train_df, test_df, valid_df, img_size):
    trgen=ImageDataGenerator()
    t_and_v_gen=ImageDataGenerator()
    msg='{0:70s} for train generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    train_gen=trgen.flow_from_dataframe(train_df, x_col='image', y_col='label', target_size=img_size,class_mode='categorical',
                                        color_mode='rgb', shuffle=True, batch_size=batch_size)
    msg='{0:70s} for valid generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    valid_gen=t_and_v_gen.flow_from_dataframe(valid_df, x_col='image', y_col='label', target_size=img_size,class_mode='categorical',
                                        color_mode='rgb', shuffle=False, batch_size=batch_size)
    # for the test_gen we want to calculate the batch size and test steps such that batch_size X test_steps= number of samples in test set
    # this insures that we go through all the sample in the test set exactly once.
    length=len(test_df)
    test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
    test_steps=int(length/test_batch_size)
    msg='{0:70s} for test generator'.format(' ')
    print(msg, '\r', end='') # prints over on the same line
    test_gen=t_and_v_gen.flow_from_dataframe(test_df, x_col='image', y_col='label', target_size=img_size,class_mode='categorical',
                                        color_mode='rgb', shuffle=False, batch_size=test_batch_size)
    # from the generator we can get information we will need later
    classes=list(train_gen.class_indices.keys())
    class_indices=list(train_gen.class_indices.values())
    class_count=len(classes)
    labels=test_gen.labels
    print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)
    return train_gen, test_gen, valid_gen, test_batch_size, test_steps, classes


batch_size=20
train_gen, test_gen, valid_gen, test_batch_size, test_steps, classes=make_gens(batch_size, train_df, test_df, valid_df, img_size)
# Out:
# Found 4400 validated image filenames belonging to 22 classes.          for train generator
# Found 110 validated image filenames belonging to 22 classes.           for valid generator
# Found 110 validated image filenames belonging to 22 classes.           for test generator
# test batch size:  55   test steps:  2  number of classes :  22

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(25, 25))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):        
        plt.subplot(5, 5, i + 1)
        image=images[i] /255       
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=18)
        plt.axis('off')
    plt.show()
    
show_image_samples(train_gen )

# %%
def print_in_color(txt_msg,fore_tupple=(0,255,255),back_tupple=(100,100,100)):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    # default parameter print in cyan foreground and gray background
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# example default print
msg='test of default colors'
print_in_color(msg)
# Out:
# test of default colors

# %%
def make_model(img_size, lr, mod_num=3):  
    img_shape=(img_size[0], img_size[1], 3)
    if mod_num == 0:
        base_model=tf.keras.applications.efficientnet.EfficientNetB0(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B0 model'
    elif mod_num == 3:
        base_model=tf.keras.applications.efficientnet.EfficientNetB3(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
        msg='Created EfficientNet B3 model'
    elif mod_num == 5:
        base_model=tf.keras.applications.efficientnet.EfficientNetB5(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
        msg='Created EfficientNet B5 model'
        
    else:
        base_model=tf.keras.applications.efficientnet.EfficientNetB7(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max')
        msg='Created EfficientNet B7 model'

    base_model.trainable=True
    x=base_model.output
    x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
    x = Dense(256, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                    bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
    x=Dropout(rate=.4, seed=123)(x)       
    output=Dense(class_count, activation='softmax')(x)
    model=Model(inputs=base_model.input, outputs=output)
    model.compile(Adam(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy']) 
    msg=msg + f' with initial learning rate set to {lr}'
    print_in_color(msg)
    return model

lr=.001
model=make_model((200,300), lr) # using B3 model by default
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Created EfficientNet B3 model with initial learning rate set to 0.001

# %%
class LR_ASK(keras.callbacks.Callback):
    def __init__ (self, model, epochs,  ask_epoch, dwell=True, factor=.4): # initialization of the callback
        super(LR_ASK, self).__init__()
        self.model=model               
        self.ask_epoch=ask_epoch
        self.epochs=epochs
        self.ask=True # if True query the user on a specified epoch
        self.lowest_vloss=np.inf
        self.lowest_aloss=np.inf
        self.best_weights=self.model.get_weights() # set best weights to model's initial weights
        self.best_epoch=1
        self.plist=[]
        self.alist=[]
        self.dwell= dwell
        self.factor=factor
        
    def get_list(self): # define a function to return the list of % validation change
        return self.plist, self.alist
    def on_train_begin(self, logs=None): # this runs on the beginning of training
        if self.ask_epoch == 0: 
            print('you set ask_epoch = 0, ask_epoch will be set to 1', flush=True)
            self.ask_epoch=1
        if self.ask_epoch >= self.epochs: # you are running for epochs but ask_epoch>epochs
            print('ask_epoch >= epochs, will train for ', epochs, ' epochs', flush=True)
            self.ask=False # do not query the user
        if self.epochs == 1:
            self.ask=False # running only for 1 epoch so do not query user
        else:
            msg =f'Training will proceed until epoch {ask_epoch} then you will be asked to' 
            print_in_color(msg )
            msg='enter H to halt training or enter an integer for how many more epochs to run then be asked again'
            print_in_color(msg)
            if self.dwell:
                msg='learning rate will be automatically adjusted during training'
                print_in_color(msg, (0,255,0))
        self.start_time= time.time() # set the time at which training started
       
    def on_train_end(self, logs=None):   # runs at the end of training  
        msg=f'loading model with weights from epoch {self.best_epoch}'
        print_in_color(msg, (0,255,255))
        model.set_weights(self.best_weights) # set the weights of the model to the best weights
        tr_duration=time.time() - self.start_time   # determine how long the training cycle lasted         
        hours = tr_duration // 3600
        minutes = (tr_duration - (hours * 3600)) // 60
        seconds = tr_duration - ((hours * 3600) + (minutes * 60))
        msg = f'training elapsed time was {str(hours)} hours, {minutes:4.1f} minutes, {seconds:4.2f} seconds)'
        print_in_color (msg) # print out training duration time
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        vloss=logs.get('val_loss')  # get the validation loss for this epoch
        aloss=logs.get('loss')
        if epoch >0:
            deltav = self.lowest_vloss- vloss 
            pimprov=(deltav/self.lowest_vloss) * 100 
            self.plist.append(pimprov)
            deltaa=self.lowest_aloss-aloss
            aimprov=(deltaa/self.lowest_aloss) * 100
            self.alist.append(aimprov)
        else:
            pimprov=0.0 
            aimprov=0.0
        if vloss< self.lowest_vloss:
            self.lowest_vloss=vloss
            self.best_weights=self.model.get_weights() # set best weights to model's initial weights
            self.best_epoch=epoch + 1            
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % below lowest loss, saving weights from epoch {str(epoch + 1):3s} as best weights'
            print_in_color(msg, (0,255,0)) # green foreground
        else: # validation loss increased
            pimprov=abs(pimprov)
            msg=f'\n validation loss of {vloss:7.4f} is {pimprov:7.4f} % above lowest loss of {self.lowest_vloss:7.4f} keeping weights from epoch {str(self.best_epoch)} as best weights'
            print_in_color(msg, (255,255,0)) # yellow foreground
            if self.dwell: # if dwell is True when the validation loss increases the learning rate is automatically reduced and model weights are set to best weights
                lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                new_lr=lr * self.factor
                msg=f'learning rate was automatically adjusted from {lr:8.6f} to {new_lr:8.6f}, model weights set to best weights'
                print_in_color(msg) # cyan foreground
                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                model.set_weights(self.best_weights) # set the weights of the model to the best weights      
                
        if aloss< self.lowest_aloss:
            self.lowest_aloss=aloss        
        if self.ask: # are the conditions right to query the user?
            if epoch + 1 ==self.ask_epoch: # is this epoch the one for quering the user?
                msg='\n Enter H to end training or  an integer for the number of additional epochs to run then ask again'
                print_in_color(msg) # cyan foreground
                ans=input()
                
                if ans == 'H' or ans =='h' or ans == '0': # quit training for these conditions
                    msg=f'you entered {ans},  Training halted on epoch {epoch+1} due to user input\n'
                    print_in_color(msg)
                    self.model.stop_training = True # halt training
                else: # user wants to continue training
                    self.ask_epoch += int(ans)
                    if self.ask_epoch > self.epochs:
                        print('\nYou specified maximum epochs of as ', self.epochs, ' cannot train for ', self.ask_epoch, flush =True)
                    else:
                        msg=f'you entered {ans} Training will continue to epoch {self.ask_epoch}'
                        print_in_color(msg) # cyan foreground
                        if self.dwell==False:
                            lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
                            msg=f'current LR is  {lr:8.6f}  hit enter to keep  this LR or enter a new LR'
                            print_in_color(msg) # cyan foreground
                            ans=input(' ')
                            if ans =='':
                                msg=f'keeping current LR of {lr:7.5f}'
                                print_in_color(msg) # cyan foreground
                            else:
                                new_lr=float(ans)
                                tf.keras.backend.set_value(self.model.optimizer.lr, new_lr) # set the learning rate in the optimizer
                                msg=f' changing LR to {ans}'
                                print_in_color(msg) # cyan foreground

# %%
epochs=40
ask_epoch=10
ask=LR_ASK(model, epochs,  ask_epoch)
callbacks=[ask]

# %%
history=model.fit(x=train_gen,  epochs=epochs, verbose=1, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
# Training will proceed until epoch 10 then you will be asked to
#
# enter H to halt training or enter an integer for how many more epochs to run then be asked again
#
# learning rate will be automatically adjusted during training
#
# Epoch 1/40
# 220/220 [==============================] - ETA: 0s - loss: 7.0739 - accuracy: 0.5645
#  validation loss of  4.8860 is  0.0000 % below lowest loss, saving weights from epoch 1   as best weights
#
# 220/220 [==============================] - 680s 3s/step - loss: 7.0739 - accuracy: 0.5645 - val_loss: 4.8860 - val_accuracy: 0.5636
# Epoch 2/40
# 220/220 [==============================] - ETA: 0s - loss: 2.6701 - accuracy: 0.8139
#  validation loss of  1.8409 is 62.3238 % below lowest loss, saving weights from epoch 2   as best weights
#
# 220/220 [==============================] - 784s 4s/step - loss: 2.6701 - accuracy: 0.8139 - val_loss: 1.8409 - val_accuracy: 0.8364
# Epoch 3/40
# 220/220 [==============================] - ETA: 0s - loss: 1.2106 - accuracy: 0.9025
#  validation loss of  1.3988 is 24.0115 % below lowest loss, saving weights from epoch 3   as best weights
#
# 220/220 [==============================] - 1072s 5s/step - loss: 1.2106 - accuracy: 0.9025 - val_loss: 1.3988 - val_accuracy: 0.8182
# Epoch 4/40
# 220/220 [==============================] - ETA: 0s - loss: 0.8949 - accuracy: 0.9043
#  validation loss of  1.4677 is  4.9196 % above lowest loss of  1.3988 keeping weights from epoch 3 as best weights
#
# learning rate was automatically adjusted from 0.001000 to 0.000400, model weights set to best weights
#
# 220/220 [==============================] - 626s 3s/step - loss: 0.8949 - accuracy: 0.9043 - val_loss: 1.4677 - val_accuracy: 0.7000
# Epoch 5/40
# 220/220 [==============================] - ETA: 0s - loss: 0.7366 - accuracy: 0.9514
#  validation loss of  0.9882 is 29.3531 % below lowest loss, saving weights from epoch 5   as best weights
#
# 220/220 [==============================] - 486s 2s/step - loss: 0.7366 - accuracy: 0.9514 - val_loss: 0.9882 - val_accuracy: 0.8545
# Epoch 6/40
# 220/220 [==============================] - ETA: 0s - loss: 0.5305 - accuracy: 0.9716
#  validation loss of  0.8121 is 17.8255 % below lowest loss, saving weights from epoch 6   as best weights
#
# 220/220 [==============================] - 474s 2s/step - loss: 0.5305 - accuracy: 0.9716 - val_loss: 0.8121 - val_accuracy: 0.8727
# Epoch 7/40
# 220/220 [==============================] - ETA: 0s - loss: 0.4509 - accuracy: 0.9734
#  validation loss of  0.7625 is  6.1005 % below lowest loss, saving weights from epoch 7   as best weights
#
# 220/220 [==============================] - 523s 2s/step - loss: 0.4509 - accuracy: 0.9734 - val_loss: 0.7625 - val_accuracy: 0.8727
# Epoch 8/40
# 220/220 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.9791
#  validation loss of  0.8484 is 11.2598 % above lowest loss of  0.7625 keeping weights from epoch 7 as best weights
#
# learning rate was automatically adjusted from 0.000400 to 0.000160, model weights set to best weights
#
# 220/220 [==============================] - 844s 4s/step - loss: 0.4062 - accuracy: 0.9791 - val_loss: 0.8484 - val_accuracy: 0.8636
# Epoch 9/40
# 220/220 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.9836
#  validation loss of  0.6915 is  9.3210 % below lowest loss, saving weights from epoch 9   as best weights
#
# 220/220 [==============================] - 736s 3s/step - loss: 0.3833 - accuracy: 0.9836 - val_loss: 0.6915 - val_accuracy: 0.8727
# Epoch 10/40
# 220/220 [==============================] - ETA: 0s - loss: 0.3462 - accuracy: 0.9905
#  validation loss of  0.6906 is  0.1269 % below lowest loss, saving weights from epoch 10  as best weights
#
#
#  Enter H to end training or  an integer for the number of additional epochs to run then ask again
#
# you entered h,  Training halted on epoch 10 due to user input
#
#
# 220/220 [==============================] - 2021s 9s/step - loss: 0.3462 - accuracy: 0.9905 - val_loss: 0.6906 - val_accuracy: 0.8818
# loading model with weights from epoch 10
#
# training elapsed time was 2.0 hours, 17.0 minutes, 25.97 seconds)

# %%
def predictor(test_gen):    
    y_pred= []
    error_list=[]
    error_pred_list = []
    y_true=test_gen.labels
    classes=list(test_gen.class_indices.keys())
    class_count=len(classes)
    errors=0
    preds=model.predict(test_gen, verbose=1)
    tests=len(preds)    
    for i, p in enumerate(preds):  
        file=test_gen.filenames[i]        
        pred_index=np.argmax(p)         
        true_index=test_gen.labels[i]  # labels are integer values        
        if pred_index != true_index: # a misclassification has occurred                                           
            errors=errors + 1
            file=test_gen.filenames[i]            
            error_class=classes[pred_index]
            t=(file, error_class)
            error_list.append(t)            
        y_pred.append(pred_index)
            
    acc=( 1-errors/tests) * 100
    msg=f'there were {errors} errors in {tests} tests for an accuracy of {acc:6.2f}'
    print_in_color(msg, (0,255,255), (100,100,100)) # cyan foreground
    ypred=np.array(y_pred)
    ytrue=np.array(y_true)
    f1score=f1_score(ytrue, ypred, average='weighted')* 100
    if class_count <=30:
        cm = confusion_matrix(ytrue, ypred )
        # plot the confusion matrix
        plt.figure(figsize=(12, 8))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(class_count)+.5, classes, rotation=90)
        plt.yticks(np.arange(class_count)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes, digits= 4) # create classification report
    print("Classification Report:\n----------------------\n", clr)
    return errors, tests, error_list, f1score

# %%
errors, tests, error_list, f1score =predictor(test_gen)
# Out:
# 2/2 [==============================] - 5s 734ms/step
# there were 11 errors in 110 tests for an accuracy of  90.00
# Classification Report:
# ----------------------
#                                     precision    recall  f1-score   support
#
# Alstonia Scholaris diseased (P2a)     1.0000    1.0000    1.0000         5
#  Alstonia Scholaris healthy (P2b)     1.0000    1.0000    1.0000         5
#              Arjun diseased (P1a)     1.0000    0.8000    0.8889         5
#               Arjun healthy (P1b)     0.8333    1.0000    0.9091         5
#               Bael diseased (P4b)     1.0000    1.0000    1.0000         5
#                Basil healthy (P8)     1.0000    1.0000    1.0000         5
#            Chinar diseased (P11b)     1.0000    0.8000    0.8889         5
#             Chinar healthy (P11a)     0.8333    1.0000    0.9091         5
#              Gauva diseased (P3b)     0.8000    0.8000    0.8000         5
#               Gauva healthy (P3a)     1.0000    1.0000    1.0000         5
#              Jamun diseased (P5b)     1.0000    0.8000    0.8889         5
#               Jamun healthy (P5a)     0.8333    1.0000    0.9091         5
#           Jatropha diseased (P6b)     1.0000    1.0000    1.0000         5
#            Jatropha healthy (P6a)     1.0000    1.0000    1.0000         5
#             Lemon diseased (P10b)     1.0000    0.2000    0.3333         5
#              Lemon healthy (P10a)     0.5556    1.0000    0.7143         5
#              Mango diseased (P0b)     0.8333    1.0000    0.9091         5
#               Mango healthy (P0a)     1.0000    1.0000    1.0000         5
#        Pomegranate diseased (P9b)     0.8333    1.0000    0.9091         5
#         Pomegranate healthy (P9a)     1.0000    0.8000    0.8889         5
#   Pongamia Pinnata diseased (P7b)     1.0000    0.6000    0.7500         5
#    Pongamia Pinnata healthy (P7a)     0.8333    1.0000    0.9091         5
#
#                          accuracy                         0.9000       110
#                         macro avg     0.9253    0.9000    0.8913       110
#                      weighted avg     0.9253    0.9000    0.8913       110

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(25,10))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].scatter(Epochs, tloss, s=100, c='red')    
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs', fontsize=18)
    axes[0].set_ylabel('Loss', fontsize=18)
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].scatter(Epochs, tacc, s=100, c='red')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs', fontsize=18)
    axes[1].set_ylabel('Accuracy', fontsize=18)
    axes[1].legend()
    plt.tight_layout    
    plt.show()
    return index_loss

# %%
loss_index=tr_plot(history,0)

# %%
images_to_predict_path='images to predict'
image_to_predict=os.listdir(images_to_predict_path)

images=[]
for image in range(len(image_to_predict)):
    images.append(os.path.join(images_to_predict_path+'/'+image_to_predict[image]))

for i in range(len(images)):
    img = tf.keras.utils.load_img(
        images[i], target_size=(200, 300)
    )

    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print(
        "This image from ( {} ) most likely belongs to {} with a {:.2f} percent confidence."
        .format(images[i],classes[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# 1/1 [==============================] - 11s 11s/step
# This image from ( images to predict/0020_0271.JPG ) most likely belongs to Pomegranate diseased (P9b) with a 10.09 percent confidence.
# 1/1 [==============================] - 1s 626ms/step
# This image from ( images to predict/0016_0118.JPG ) most likely belongs to Bael diseased (P4b) with a 6.40 percent confidence.
# 1/1 [==============================] - 0s 49ms/step
# This image from ( images to predict/0019_0276.JPG ) most likely belongs to Pongamia Pinnata diseased (P7b) with a 11.32 percent confidence.
# 1/1 [==============================] - 0s 45ms/step
# This image from ( images to predict/0008_0148.JPG ) most likely belongs to Basil healthy (P8) with a 11.06 percent confidence.
# 1/1 [==============================] - 0s 44ms/step
# This image from ( images to predict/0005_0268.JPG ) most likely belongs to Jamun healthy (P5a) with a 10.63 percent confidence.
# 1/1 [==============================] - 1s 1s/step
# This image from ( images to predict/0003_0179.JPG ) most likely belongs to Alstonia Scholaris healthy (P2b) with a 8.84 percent confidence.
# 1/1 [==============================] - 0s 121ms/step
# This image from ( images to predict/0015_0123.JPG ) most likely belongs to Gauva diseased (P3b) with a 9.58 percent confidence.
# 1/1 [==============================] - 0s 54ms/step
# This image from ( images to predict/0001_0170.JPG ) most likely belongs to Mango healthy (P0a) with a 9.09 percent confidence.
